# %%
import pandas as pd

# %%
data=pd.read_csv("Sample 2ND YR.csv")

# %%
data
# Out:
#     CANDIDATE ID CANDIDATE NAME  FATHER  GROUP  OTHER  TESTID   Q1   Q2   Q3  \
# 0              0     ANSWER KEY     NaN    NaN    NaN     4.0    C    C    C
# 1     23AG1A6691            NaN     NaN    NaN    NaN     4.0    C    C    D
# 2     23AG1 6702            NaN     NaN    NaN    NaN     4.0    C    A    C
# 3     23AG1A6747            NaN     NaN    NaN    NaN     4.0    C    C    C
# 4     23AG1A6712            NaN     NaN    NaN    NaN     4.0    C    C    C
# ..           ...            ...     ...    ...    ...     ...  ...  ...  ...
# 302            0              C     NaN    NaN    NaN     NaN  210  145  114
# 303            0              D     NaN    NaN    NaN     NaN   18   22  128
# 304            0        CORRECT     NaN    NaN    NaN     NaN  210  145  114
# 305            0      INCORRECT     NaN    NaN    NaN     NaN   85  152  185
# 306            0     UNANSWERED     NaN    NaN    NaN     NaN    4    2    0
#
# ...

# %%
data.head()
# Out:
#   CANDIDATE ID CANDIDATE NAME  FATHER  GROUP  OTHER  TESTID Q1 Q2 Q3 Q4  ...  \
# 0            0     ANSWER KEY     NaN    NaN    NaN     4.0  C  C  C  A  ...
# 1   23AG1A6691            NaN     NaN    NaN    NaN     4.0  C  C  D  A  ...
# 2   23AG1 6702            NaN     NaN    NaN    NaN     4.0  C  A  C  A  ...
# 3   23AG1A6747            NaN     NaN    NaN    NaN     4.0  C  C  C  A  ...
# 4   23AG1A6712            NaN     NaN    NaN    NaN     4.0  C  C  C  A  ...
#
#   Q94 Q95 Q96 Q97 Q98 Q99 Q100   TOTR  TOTW TOTL
# 0   B   C   A   A   A   A    A  100.0   0.0  0.0
# 1   A   B   C   A   A   A    A   57.0  42.0  0.0
# 2   A   A   C   A   A   A    A   56.0  43.0  0.0
# 3   A   A   C   A   A   A    A   56.0  43.0  0.0
# 4   A   A   C   A   A   A    A   55.0  44.0  0.0
#
# [5 rows x 109 columns]

# %%
dsaDf=data.iloc[:,0:56]
dsaDf
# Out:
#     CANDIDATE ID CANDIDATE NAME  FATHER  GROUP  OTHER  TESTID   Q1   Q2   Q3  \
# 0              0     ANSWER KEY     NaN    NaN    NaN     4.0    C    C    C
# 1     23AG1A6691            NaN     NaN    NaN    NaN     4.0    C    C    D
# 2     23AG1 6702            NaN     NaN    NaN    NaN     4.0    C    A    C
# 3     23AG1A6747            NaN     NaN    NaN    NaN     4.0    C    C    C
# 4     23AG1A6712            NaN     NaN    NaN    NaN     4.0    C    C    C
# ..           ...            ...     ...    ...    ...     ...  ...  ...  ...
# 302            0              C     NaN    NaN    NaN     NaN  210  145  114
# 303            0              D     NaN    NaN    NaN     NaN   18   22  128
# 304            0        CORRECT     NaN    NaN    NaN     NaN  210  145  114
# 305            0      INCORRECT     NaN    NaN    NaN     NaN   85  152  185
# 306            0     UNANSWERED     NaN    NaN    NaN     NaN    4    2    0
#
# ...

# %%
 dsaDf.drop(['FATHER','GROUP','OTHER','TESTID'] ,axis=1,inplace=True)

# %%
dsaDf
# Out:
#     CANDIDATE ID CANDIDATE NAME   Q1   Q2   Q3   Q4   Q5   Q6   Q7   Q8  ...  \
# 0              0     ANSWER KEY    C    C    C    A    B    B    B    B  ...
# 1     23AG1A6691            NaN    C    C    D    A    A    B    C    B  ...
# 2     23AG1 6702            NaN    C    A    C    A    A    B    B    B  ...
# 3     23AG1A6747            NaN    C    C    C    A    A    B    B    D  ...
# 4     23AG1A6712            NaN    C    C    C    A    A    B    B    D  ...
# ..           ...            ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 302            0              C  210  145  114   17   19   26   83   22  ...
# 303            0              D   18   22  128   32    6   16   72   59  ...
# 304            0        CORRECT  210  145  114  211   17  157  108  120  ...
# 305            0      INCORRECT   85  152  185   87  282  138  185  173  ...
# 306            0     UNANSWERED    4    2    0    1    0    4    6    6  ...
#
# ...

# %%
daDf=data.iloc[:,[0]+list(range(56,107))]
daDf
# Out:
#     CANDIDATE ID  Q51  Q52  Q53  Q54  Q55  Q56  Q57  Q58  Q59  ...  Q92  Q93  \
# 0              0    C    C    C    A    D    B    C    B    A  ...    B    A
# 1     23AG1A6691    C    C    C    A    D    B    D    A    A  ...    A    A
# 2     23AG1 6702    C    B    C    B    B    C    C    A    D  ...    B    A
# 3     23AG1A6747    B    B    B    A    A    C    C    B    A  ...    B    A
# 4     23AG1A6712    B    B    B    A    A    C    C    B    A  ...    B    A
# ..           ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 302            0  189   60  117   24   45   77  100  152   68  ...   23   32
# 303            0   11   51   29   28   27   20   48   22   58  ...   12   11
# 304            0  189   60  117  164   27   92  100   56  119  ...   80  172
# 305            0  107  235  175  130  267  195  194  239  174  ...  217  122
# 306            0    3    4    7    5    5   12    5    4    6  ...    2    5
#
# ...

# %%
NewDf=daDf.copy()
NewDf.drop(['CANDIDATE ID','TOTR'],axis=1,inplace=True)
NewDf
# Out:
#      Q51  Q52  Q53  Q54  Q55  Q56  Q57  Q58  Q59  Q60  ...  Q91  Q92  Q93  \
# 0      C    C    C    A    D    B    C    B    A    D  ...    A    B    A
# 1      C    C    C    A    D    B    D    A    A    D  ...    B    A    A
# 2      C    B    C    B    B    C    C    A    D    D  ...    B    B    A
# 3      B    B    B    A    A    C    C    B    A    D  ...    D    B    A
# 4      B    B    B    A    A    C    C    B    A    D  ...    D    B    A
# ..   ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 302  189   60  117   24   45   77  100  152   68   61  ...   62   23   32
# 303   11   51   29   28   27   20   48   22   58   98  ...   25   12   11
# 304  189   60  117  164   27   92  100   56  119   98  ...   53   80  172
# 305  107  235  175  130  267  195  194  239  174  187  ...  239  217  122
# 306    3    4    7    5    5   12    5    4    6   14  ...    7    2    5
#
#      Q94  Q95  Q96  Q97  Q98  Q99 Q100
# 0      B    C    A    A    A    A    A
# ...

# %%
Marks=[]
Right=[]
Wrong=[]
n=0
while(n<NewDf.shape[0]):
    marks=0
    right=0
    wrong=0
    for i in NewDf:
        if NewDf[i][n]==NewDf[i][0] or i=='Q70':
            marks+=1
            right+=1
        else:
            wrong+=1
    Marks.append(marks)
    Right.append(right)
    Wrong.append(wrong)
    n+=1
Marks
# Out:
# [50,
#  37,
#  33,
#  32,
#  33,
#  34,
#  30,
#  31,
#  29,
#  33,
#  33,
#  25,
#  25,
#  29,
#  30,
#  30,
#  28,
#  30,
#  30,
#  28,
#  29,
#  31,
#  30,
#  30,
#  24,
#  31,
#  31,
#  28,
#  28,
#  29,
#  25,
#  23,
#  30,
#  26,
#  25,
#  29,
#  27,
#  26,
#  25,
#  21,
#  25,
#  25,
#  27,
#  25,
#  22,
#  26,
#  26,
#  27,
#  22,
#  27,
#  24,
#  25,
#  25,
#  25,
#  27,
#  23,
#  23,
#  25,
#  25,
#  25,
#  21,
#  26,
#  27,
#  25,
#  22,
#  20,
#  19,
#  22,
#  26,
#  24,
#  17,
#  21,
#  22,
#  24,
#  22,
#  20,
#  19,
#  23,
#  22,
#  19,
#  19,
#  17,
#  25,
#  23,
#  24,
#  24,
#  24,
#  20,
#  25,
#  23,
#  21,
#  21,
#  22,
#  20,
#  25,
#  24,
#  19,
#  21,
#  19,
#  23,
#  20,
#  18,
#  20,
#  16,
#  19,
#  19,
#  23,
#  19,
#  21,
#  18,
#  28,
#  23,
#  19,
#  21,
#  24,
#  18,
#  21,
#  16,
#  19,
#  22,
#  20,
#  23,
#  19,
#  22,
#  19,
#  18,
#  25,
#  23,
#  18,
#  24,
#  22,
#  18,
#  20,
#  23,
#  15,
#  18,
#  20,
#  23,
#  18,
#  17,
#  19,
#  24,
# ...

# %%
daDf['Da Marks']=Marks
daDf['Right DA']=Right
daDf['Wrong DA']=Wrong
daDf
# Out:
# C:\Users\revan\AppData\Local\Temp\ipykernel_11136\2099122297.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   daDf['Da Marks']=Marks
# C:\Users\revan\AppData\Local\Temp\ipykernel_11136\2099122297.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   daDf['Right DA']=Right
# C:\Users\revan\AppData\Local\Temp\ipykernel_11136\2099122297.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# ...

# %%
daDf.columns = daDf.columns.str.strip()
daDf
# Out:
#     CANDIDATE ID  Q51  Q52  Q53  Q54  Q55  Q56  Q57  Q58  Q59  ...  Q95  Q96  \
# 0              0    C    C    C    A    D    B    C    B    A  ...    C    A
# 1     23AG1A6691    C    C    C    A    D    B    D    A    A  ...    B    C
# 2     23AG1 6702    C    B    C    B    B    C    C    A    D  ...    A    C
# 3     23AG1A6747    B    B    B    A    A    C    C    B    A  ...    A    C
# 4     23AG1A6712    B    B    B    A    A    C    C    B    A  ...    A    C
# ..           ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 302            0  189   60  117   24   45   77  100  152   68  ...   14  109
# 303            0   11   51   29   28   27   20   48   22   58  ...   16   27
# 304            0  189   60  117  164   27   92  100   56  119  ...   14   37
# 305            0  107  235  175  130  267  195  194  239  174  ...  281  254
# 306            0    3    4    7    5    5   12    5    4    6  ...    4    8
#
# ...

# %%
daDf.sort_values(by='Da Marks', ascending=False, inplace=True)
daDf
# Out:
# C:\Users\revan\AppData\Local\Temp\ipykernel_11136\1409575548.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   daDf.sort_values(by='Da Marks', ascending=False, inplace=True)
#     CANDIDATE ID  Q51  Q52  Q53  Q54  Q55  Q56  Q57  Q58  Q59  ...  Q95  Q96  \
# 0              0    C    C    C    A    D    B    C    B    A  ...    C    A
# 1     23AG1A6691    C    C    C    A    D    B    D    A    A  ...    B    C
# 5     23AG1A6678    C    A    C    A    B    C    D    B    A  ...    A    C
# 9     23AG1A7204    C    B    C    A    D    A    C    D    C  ...    A    C
# 10    23AG1A7246    C    B    C    A    D    A    C    D    D  ...    A    C
# ..           ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# ...

# %%
daDf['Rank'] = list(range(0,daDf.shape[0]))
daDf
# Out:
# C:\Users\revan\AppData\Local\Temp\ipykernel_11136\673268983.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   daDf['Rank'] = list(range(0,daDf.shape[0]))
#     CANDIDATE ID  Q51  Q52  Q53  Q54  Q55  Q56  Q57  Q58  Q59  ...  Q96  Q97  \
# 0              0    C    C    C    A    D    B    C    B    A  ...    A    A
# 1     23AG1A6691    C    C    C    A    D    B    D    A    A  ...    C    A
# 5     23AG1A6678    C    A    C    A    B    C    D    B    A  ...    C    A
# 9     23AG1A7204    C    B    C    A    D    A    C    D    C  ...    C    A
# 10    23AG1A7246    C    B    C    A    D    A    C    D    D  ...    C    A
# ..           ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# ...

# %%
RankDf=daDf[['Rank','CANDIDATE ID','Da Marks','TOTR']]
RankDf['DSA MArks']=RankDf['TOTR']-RankDf['Da Marks']
RankDf
# Out:
# C:\Users\revan\AppData\Local\Temp\ipykernel_11136\2360171768.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RankDf['DSA MArks']=RankDf['TOTR']-RankDf['Da Marks']
#      Rank CANDIDATE ID  Da Marks   TOTR  DSA MArks
# 0       0            0        50  100.0       50.0
# 1       1   23AG1A6691        37   57.0       20.0
# 5       2   23AG1A6678        34   53.0       19.0
# 9       3   23AG1A7204        33   51.0       18.0
# 10      4   23AG1A7246        33   51.0       18.0
# ..    ...          ...       ...    ...        ...
# 302   302            0         1    NaN        NaN
# 303   303            0         1    NaN        NaN
# 304   304            0         1    NaN        NaN
# ...
